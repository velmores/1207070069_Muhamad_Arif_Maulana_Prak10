# %%
from matplotlib import pyplot as plt
import cv2

love = cv2.imread('foto/llove.jpg')
love = cv2.cvtColor(love, cv2.COLOR_BGR2RGB)

kumpulan_love = cv2.imread('foto/kumpulanlove.JPEG')
kumpulan_love = cv2.cvtColor(kumpulan_love, cv2.COLOR_BGR2RGB)

plt.subplot(121)
plt.imshow(love)
plt.title('Love')
plt.subplot(122)
plt.imshow(kumpulan_love)
plt.title('Kumpulan Love')
plt.show()

# %% [markdown]
# Template Matching

# %%
import cv2
import numpy as np

img_rgb = cv2.imread('foto/kumpulanlove.JPEG')
img_gray = cv2.cvtColor(img_rgb, cv2.COLOR_BGR2GRAY)

template = cv2.imread('foto/llove.jpg',0)

w, h = template.shape[::-1]

res = cv2.matchTemplate(img_gray,template,cv2.TM_CCOEFF_NORMED)

threshold = 0.15
loc = np.where(res >= threshold)
lspoint=[]
lspoint2=[]
count = 0 
for pt in zip(*loc[::-1]):
    if pt[0] not in lspoint and pt[1] not in lspoint2:
        cv2.rectangle(img_rgb, pt, (pt[0] + w, pt[1] + h), (0,255,255), 2)
        for i in range(((pt[0])-9), ((pt[0])+9),1):
            lspoint.append(i)
        for k in range(((pt[1])-9), ((pt[1])+9),1):
            lspoint2.append(k)
            count+=1
    else:
        continue
print ("Jumlah objek ditemukan ", count)

cv2.imshow('Deteksi Objek', img_rgb)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# Jumlah objek ditemukan  702
